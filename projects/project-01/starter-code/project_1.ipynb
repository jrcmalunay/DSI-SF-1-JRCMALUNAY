# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# The data describes the rate, math, and verbal scores for all 50 states. The last part of the list looks to be the average of all the states.

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# Yes, it does look complete. However, it does look out of structure. Overall, it could visually be cleaner.

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %%
#Created an emp
dataset = {}
for i in rows:
    dataset.values() 
    
dataset
# Out:
# {}

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
#imported the data of sat_scores.csv
import csv

sat_data_path = '../assets/sat_scores.csv'
rows = []

with open(sat_data_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        rows.append(row)

# %% [markdown]
# ##### 5. Print the data

# %%
#Called and printed all the data in list rows
print rows
# Out:
# [['State', 'Rate', 'Verbal', 'Math'], ['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NB', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
#Popped out the first list in rows

header = rows.pop(0)
print header
# Out:
# ['State', 'Rate', 'Verbal', 'Math']

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
#Made a for loop to call all states, based on abbreviation, to a new list. If length of first column is longer than 2
#characters, it would pop out the list
state = []
for index in rows:
    if len(index[0]) > 2:
        rows.pop()
    else:
        state.append(index[0])
        
state
# Out:
# ['CT',
#  'NJ',
#  'MA',
#  'NY',
#  'NH',
#  'RI',
#  'PA',
#  'VT',
#  'ME',
#  'VA',
#  'DE',
#  'MD',
#  'NC',
#  'GA',
#  'IN',
#  'SC',
#  'DC',
#  'OR',
#  'FL',
#  'WA',
#  'TX',
#  'HI',
#  'AK',
#  'CA',
#  'AZ',
#  'NV',
#  'CO',
#  'OH',
#  'MT',
#  'WV',
#  'ID',
#  'TN',
#  'NM',
#  'IL',
#  'KY',
#  'WY',
#  'MI',
#  'MN',
#  'KS',
#  'AL',
#  'NB',
#  'OK',
#  'MO',
#  'LA',
#  'WI',
#  'AR',
#  'UT',
#  'IA',
#  'SD',
#  'ND',
#  'MS']

# %% [markdown]
# ##### 8. Print the types of each column

# %%
#Wrote a for looop to iterate through each list in the list rows. Used and index to call each column and determined
#all of the indicies are string types
#State, Rate, Verbal, and Math all all string types

for index in rows:
    print type(index[0]), type(index[1]), type(index[2]), type(index[3])
# Out:
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>
# <type 'str'> <type 'str'> <type 'str'> <type 'str'>

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
#Yes, as we see above, all of the types are strings. We must convert the 2nd, 3rd, and 4th columns to integers
#DONT FORGET TO ADD THEM IN A LIST!

rate = []
verbal = []
math = []

for index in rows:
    x = int(index[1])
    y = int(index[2])
    z = int(index[3])
    rate.append(x)
    verbal.append(y)
    math.append(z)
    
print rate
print verbal
print math

#print "Verbal:", verbal
#print "Math:", math
# Out:
# [82, 81, 79, 77, 72, 71, 71, 69, 69, 68, 67, 65, 65, 63, 60, 57, 56, 55, 54, 53, 53, 52, 51, 51, 34, 33, 31, 26, 23, 18, 17, 13, 13, 12, 12, 11, 11, 9, 9, 9, 8, 8, 8, 7, 6, 6, 5, 5, 4, 4, 4]
# [509, 499, 511, 495, 520, 501, 500, 511, 506, 510, 501, 508, 493, 491, 499, 486, 482, 526, 498, 527, 493, 485, 514, 498, 523, 509, 539, 534, 539, 527, 543, 562, 551, 576, 550, 547, 561, 580, 577, 559, 562, 567, 577, 564, 584, 562, 575, 593, 577, 592, 566]
# [510, 513, 515, 505, 516, 499, 499, 506, 500, 501, 499, 510, 499, 489, 501, 488, 474, 526, 499, 527, 499, 515, 510, 517, 525, 515, 542, 439, 539, 512, 542, 553, 542, 589, 550, 545, 572, 589, 580, 554, 568, 561, 577, 562, 596, 550, 570, 603, 582, 599, 551]

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
database = {k[0]:[x for x in rate] for k in rows}
database
# Out:
# {'AK': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'AL': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'AR': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'AZ': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'CA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'CO': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'CT': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'DC': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'DE': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'FL': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'GA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'HI': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'IA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'ID': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'IL': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'IN': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'KS': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'KY': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'LA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MD': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'ME': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MI': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MN': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MO': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MS': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'MT': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NB': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NC': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'ND': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NH': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NJ': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NM': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NV': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'NY': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'OH': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'OK': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'OR': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'PA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'RI': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'SC': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'SD': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'TN': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'TX': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'UT': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'VA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'VT': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'WA': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'WI': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'WV': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4],
#  'WY': [82,
#   81,
#   79,
#   77,
#   72,
#   71,
#   71,
#   69,
#   69,
#   68,
#   67,
#   65,
#   65,
#   63,
#   60,
#   57,
#   56,
#   55,
#   54,
#   53,
#   53,
#   52,
#   51,
#   51,
#   34,
#   33,
#   31,
#   26,
#   23,
#   18,
#   17,
#   13,
#   13,
#   12,
#   12,
#   11,
#   11,
#   9,
#   9,
#   9,
#   8,
#   8,
#   8,
#   7,
#   6,
#   6,
#   5,
#   5,
#   4,
#   4,
#   4]}

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
data_rate = {k[1]:[x[1] for x in state] for k in header}
print data_rate,
# Out:
# {'a': ['T', 'J', 'A', 'Y', 'H', 'I', 'A', 'T', 'E', 'A', 'E', 'D', 'C', 'A', 'N', 'C', 'C', 'R', 'L', 'A', 'X', 'I', 'K', 'A', 'Z', 'V', 'O', 'H', 'T', 'V', 'D', 'N', 'M', 'L', 'Y', 'Y', 'I', 'N', 'S', 'L', 'B', 'K', 'O', 'A', 'I', 'R', 'T', 'A', 'D', 'D', 'S'], 'e': ['T', 'J', 'A', 'Y', 'H', 'I', 'A', 'T', 'E', 'A', 'E', 'D', 'C', 'A', 'N', 'C', 'C', 'R', 'L', 'A', 'X', 'I', 'K', 'A', 'Z', 'V', 'O', 'H', 'T', 'V', 'D', 'N', 'M', 'L', 'Y', 'Y', 'I', 'N', 'S', 'L', 'B', 'K', 'O', 'A', 'I', 'R', 'T', 'A', 'D', 'D', 'S'], 't': ['T', 'J', 'A', 'Y', 'H', 'I', 'A', 'T', 'E', 'A', 'E', 'D', 'C', 'A', 'N', 'C', 'C', 'R', 'L', 'A', 'X', 'I', 'K', 'A', 'Z', 'V', 'O', 'H', 'T', 'V', 'D', 'N', 'M', 'L', 'Y', 'Y', 'I', 'N', 'S', 'L', 'B', 'K', 'O', 'A', 'I', 'R', 'T', 'A', 'D', 'D', 'S']}

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
#Created 3 variables with sorted lists of rate, verbal, and math respectively. Took the first and last value of each 
#list

x = sorted(rate)
print "Rate:"
print "Min:", x[0]
print "Max:", x[-1]

y = sorted(verbal)
print "Verbal:"
print "Min:", y[0]
print "Max:", y[-1]

z = sorted(math)
print "Math:"
print "Min:", z[0]
print "Max:", z[-1]
# Out:
# Rate:
# Min: 4
# Max: 82
# Verbal:
# Min: 482
# Max: 593
# Math:
# Min: 439
# Max: 603

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
import numpy as np

def standdev(value):
    s_dev = [np.value(x) for x in rate]
    return s_dev

standdev(rate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-530-ec4d27e11d26> in <module>()
#       5     return s_dev
#       6
# ----> 7 standdev(rate)
#
# <ipython-input-530-ec4d27e11d26> in standdev(value)
#       2
#       3 def standdev(value):
# ----> 4     s_dev = [np.value(x) for x in rate]
#       5     return s_dev
#       6
#
# AttributeError: 'module' object has no attribute 'value'

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %% [markdown]
# ##### 15. Plot the Math distribution

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.
